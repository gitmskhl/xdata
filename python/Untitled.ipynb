# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_blobs, make_moons

# %%
import cluster

# %%
X, y = make_blobs(n_samples=200, centers=[[0, 0], [5, 5]])

# %%
def show(X, c):
    plt.figure(figsize=(7, 5))
    plt.scatter(X[:, 0], X[:, 1], c=c)
    plt.show()

# %%
show(X, y)

# %%
import importlib
importlib.reload(cluster)
import cluster

# %%
labels = cluster.KMeans(n_clusters=4).fit(X).labels_

# %%
show(X, labels)

# %%
X, y = make_moons(n_samples=200, noise=.1)

# %%
show(X, y)

# %%
labels = cluster.KMeans(n_clusters=2).fit(X).labels_
show(X, labels)
